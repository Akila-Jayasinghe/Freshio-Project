# %%
import os
import kagglehub
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
print("Acquiring data sets...")

kagglehub.login()

path = kagglehub.dataset_download("sriramr/fruits-fresh-and-rotten-for-classification")

print(f"Data set was downloaded to {path}")
# Out:
# Acquiring data sets...
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.1).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/sriramr/fruits-fresh-and-rotten-for-classification?dataset_version_number=1...
# 100%|██████████| 3.58G/3.58G [00:42<00:00, 90.7MB/s]
# Extracting files...
# Data set was downloaded to /root/.cache/kagglehub/datasets/sriramr/fruits-fresh-and-rotten-for-classification/versions/1
# Kaggle credentials set.

# %%
print("Preparing data...")

# Const
BATCH_SIZE = 32         # maximum batch size
IMG_SIZE = (224, 224)   # maximum resolution of MobileNetV2

# Define paths
dataset_dir = os.path.join(path, "dataset")
train_dir = os.path.join(dataset_dir, "train")
test_dir = os.path.join(dataset_dir, "test")

# Normalize the pixel colors from 1 to 255
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range = 20,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)


# labels
labels = list(train_generator.class_indices.keys())
print(f"\n✅ Detected classes: {labels}")

# Save to file
with open("labels.txt", "w") as f:
  for label in labels:
    f.write(label + "\n")
# Out:
# Preparing data...
# Found 2698 images belonging to 6 classes.
# Found 2698 images belonging to 6 classes.
#
# ✅ Detected classes: ['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges']

# %%
print("Building the MobileNetV2 model...")

# Cut off head
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# keep previous memory of the model
base_model.trainable = False

# Add custom head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)

# Turn raw numbers into probabilities
predictions = Dense(train_generator.num_classes, activation='softmax')(x)

# merge them
model = Model(inputs=base_model.input, outputs=predictions)


# Compile
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
    )

print("Modela architecture built successfully...")
# Out:
# Building the MobileNetV2 model...
# Modela architecture built successfully...

# %%
from IPython.core import history
print("Model training process was started... (approx. 5 - 10 mins)")


# Fit the model
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=validation_generator
)
# Out:
# Model training process was started... (approx. 5 - 10 mins)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 304s 3s/step - accuracy: 0.2866 - loss: 1.9029 - val_accuracy: 0.5990 - val_loss: 1.1300
# Epoch 2/5
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 285s 3s/step - accuracy: 0.6067 - loss: 1.0598 - val_accuracy: 0.8076 - val_loss: 0.7443
# Epoch 3/5
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 269s 3s/step - accuracy: 0.7588 - loss: 0.7628 - val_accuracy: 0.8673 - val_loss: 0.5569
# Epoch 4/5
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - accuracy: 0.8396 - loss: 0.5684 - val_accuracy: 0.8895 - val_loss: 0.4531
# Epoch 5/5
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 272s 3s/step - accuracy: 0.8657 - loss: 0.4892 - val_accuracy: 0.9062 - val_loss: 0.3804

# %%
print ("Converting the trained model into .TFLite file...")

# Create converter
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Convert
tflite_model = converter.convert()

# Save
with open("Freshio_model_v01.tflite", 'wb') as f:
  f.write(tflite_model)

print("Freshio model version 01 was successfully trained...")
# Out:
# Converting the trained model into .TFLite file...
# Saved artifact at '/tmp/tmprv2injo_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   137443318551504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318553040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318552848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318551696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318553616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318549200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318553232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318553424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318552464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318554576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318554000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318554192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318554384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318551120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318555536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318554960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318555152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318555344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318552656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318556496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318555920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318556112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318556304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318553808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318557456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318556880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318557072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318557264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318554768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318558416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318557840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318558032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318558224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318555728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318559376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318558800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318558992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318559184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318556688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318560336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318559760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318559952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318560144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318557648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318561296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318560720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318560912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318561104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318558608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318562256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318561680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318559568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318562448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318562640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318562064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979103184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979104144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318560528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137443318561488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979103952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979102992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979102800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979103376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979105104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979104528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979104720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979104912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979103760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979106064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979105488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979105680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979105872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979103568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979107024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979106448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979106640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979106832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979104336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979107984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979107408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979107600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979107792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979105296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979108944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979108368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979108560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979108752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979106256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979109904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979109328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979109520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979109712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979107216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979110864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979110288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979110480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979110672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979108176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979111824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979111248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979111440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979111632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979109136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979112784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979112208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979112400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979112592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979110096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979113744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137446070405072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979113360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979112016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979114704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979114128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979114320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979114512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979113936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979115664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979115088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979115280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979115472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979112976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979116624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979116048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979116240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979116432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979113168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979117584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979117008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979117200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979114896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979118544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979118160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979118928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979118352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979955536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979955344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979116816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979117776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979954768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979955920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979955728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979954960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979957072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979956496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979956688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979956880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979956112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979958032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979957456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979957648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979957840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979955152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979958992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979958416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979958608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979958800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979956304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979959952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979959376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979959568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979959760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979957264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979960336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979960720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979958224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979961872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979961296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979961488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979961680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979959184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979962256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979962448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979962640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979960144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979963792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979963216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979963408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979963600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979961104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979964752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979964176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979964368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979964560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979962064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979965712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979965136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979965328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979965520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979963024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979966672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979966288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979966480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979963984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979967632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979967056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979967248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979967440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979964944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979968592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979968016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979968208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979968400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979965904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979969552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979968976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979969168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979969360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979966864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979970512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979969936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979967824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979970704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979970128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979970896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979970320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978677776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978677200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979968784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442979969744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978676816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978677968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978678160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978677584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978679120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978678544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978678736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978678928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978677008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978680080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978679504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978679696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978679888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978677392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978681040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978680464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978680656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978680848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978678352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978682000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978681424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978681616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978681808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978679312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978682960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978682384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978682576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978682768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978680272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978683920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978684304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137442978684112: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Freshio model version 01 was successfully trained...
